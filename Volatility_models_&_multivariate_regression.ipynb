# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as  pd
import yfinance as yf
import statsmodels.api as sm
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.graphics.tsaplots as sgt
from scipy.stats import chi2
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima.model import ARIMA

# %%
df = pd.read_csv("Index2018.csv")
df.date = pd.to_datetime(df.date, dayfirst=True)
df.set_index('date', inplace=True)
df = df.asfreq('b')  # setting the Desired Frequency
df= df.fillna(method='ffill')  # fill missing values with forward fill
df_1= df.fillna(method='ffill')
df_ret = df_1

df['market_value'] = df.ftse
# Delete columns dax, ftse, nikkei and rename spx to market_value
df.drop(['dax', 'ftse', 'nikkei', 'spx'], axis=1, inplace=True)
df_comp = df.copy()
df_comp['returns'] = df.market_value.pct_change(1)*100
size = int(len(df_comp) * 0.8)
df, df_test = df_comp[:size], df_comp[size:]


# Remove NaN values from the DataFrame
df.dropna(inplace=True)
df
# Out:
# C:\Users\Niranjan\AppData\Local\Temp\ipykernel_4068\1895631032.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df= df.fillna(method='ffill')  # fill missing values with forward fill
# C:\Users\Niranjan\AppData\Local\Temp\ipykernel_4068\1895631032.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_1= df.fillna(method='ffill')
# C:\Users\Niranjan\AppData\Local\Temp\ipykernel_4068\1895631032.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#             market_value   returns
# date
# 1994-01-10       3440.58 -0.156704
# 1994-01-11       3413.77 -0.779229
# 1994-01-12       3372.02 -1.222988
# 1994-01-13       3360.01 -0.356166
# 1994-01-14       3400.56  1.206842
# ...                  ...       ...
# 2013-04-01       6411.74  0.000000
# 2013-04-02       6490.66  1.230867
# 2013-04-03       6420.28 -1.084327
# 2013-04-04       6344.11 -1.186397
# 2013-04-05       6249.77 -1.487049
#
# [5020 rows x 2 columns]

# %% [markdown]
# ### Creating squared returns

# %%
#creating a new column for squared returns (sq_returns)

df['sq_returns'] = df['returns'] ** 2
# Out:
# C:\Users\Niranjan\AppData\Local\Temp\ipykernel_4068\1009186006.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sq_returns'] = df['returns'] ** 2

# %% [markdown]
# ### Returns vs Squared Returns

# %%
# plotting returns and squared returns
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(df.index, df['returns'], label='Returns', color='blue')
plt.title('Returns')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(df.index, df['sq_returns'], label='Squared Returns', color='red')
plt.title('Squared Returns')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # ARCH Model

# %% [markdown]
# ### Descriptive statistics

# %%
# plot the pacf of returns 
sgt.plot_pacf(df['returns'], lags=40, zero=False, alpha=0.05, method='ols')
plt.ylim(-0.1, 0.1)  # Zoom y-axis
plt.title('PACF of Returns')
plt.show()

# %%
# plot the pacf of squared returns
sgt.plot_pacf(df['sq_returns'], lags=40, zero=False, alpha=0.05, method='ols')
plt.ylim(-0.1, 0.3)  # Zoom y-axis
plt.title('PACF of Squared Returns')
plt.show()

# %% [markdown]
# ### The arch_model() Method

# %%
from arch import arch_model

# %%
model_arch_1 = arch_model(df['returns'])
model_arch_1_fit = model_arch_1.fit()
print(model_arch_1_fit.summary())
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 6579303469.390623
# Iteration:      2,   Func. Count:     15,   Neg. LLF: 2701100877.2298183
# Iteration:      3,   Func. Count:     23,   Neg. LLF: 7009.030632045198
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 7024.035835212278
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 7010.712887007633
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 6975.418108744094
# Iteration:      7,   Func. Count:     47,   Neg. LLF: 7092.271338807877
# Iteration:      8,   Func. Count:     53,   Neg. LLF: 6973.879266228052
# Iteration:      9,   Func. Count:     59,   Neg. LLF: 6970.088048943886
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 6970.058478413694
# Iteration:     11,   Func. Count:     69,   Neg. LLF: 6970.0583674757745
# Iteration:     12,   Func. Count:     74,   Neg. LLF: 6970.058366189882
# Iteration:     13,   Func. Count:     78,   Neg. LLF: 6970.058366189167
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6970.058366189882
#             Iterations: 13
#             Function evaluations: 78
#             Gradient evaluations: 13
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -6970.06
# Distribution:                  Normal   AIC:                           13948.1
# Method:            Maximum Likelihood   BIC:                           13974.2
#                                         No. Observations:                 5020
# Date:                Fri, Aug 08 2025   Df Residuals:                     5019
# Time:                        17:39:18   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0466  1.183e-02      3.939  8.187e-05 [2.342e-02,6.981e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0109  3.004e-03      3.640  2.724e-04 [5.048e-03,1.682e-02]
# alpha[1]       0.0835  1.071e-02      7.794  6.476e-15   [6.249e-02,  0.104]
# beta[1]        0.9089  1.148e-02     79.168      0.000     [  0.886,  0.931]
# ============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# ### The simple ARCH(1)

# %%
model_arch_1 = arch_model(df['returns'], mean="Constant", vol='ARCH', p=1, q=0)
model_arch_1_fit = model_arch_1.fit()
print(model_arch_1_fit.summary())
# Out:
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 29071.83486537579
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 12040.736044828116
# Iteration:      3,   Func. Count:     20,   Neg. LLF: 7809.7227529035545
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 7660.088789376123
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 7660.088782040875
# Iteration:      6,   Func. Count:     33,   Neg. LLF: 7660.088782040906
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7660.088782040875
#             Iterations: 6
#             Function evaluations: 33
#             Gradient evaluations: 6
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -7660.09
# Distribution:                  Normal   AIC:                           15326.2
# Method:            Maximum Likelihood   BIC:                           15345.7
#                                         No. Observations:                 5020
# Date:                Fri, Aug 08 2025   Df Residuals:                     5019
# Time:                        17:39:18   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0345  1.603e-02      2.151  3.147e-02 [3.063e-03,6.590e-02]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# omega          0.9206  4.309e-02     21.365 2.855e-101 [  0.836,  1.005]
# alpha[1]       0.3684  5.040e-02      7.310  2.673e-13 [  0.270,  0.467]
# ========================================================================
#
# Covariance estimator: robust

# %% [markdown]
# ### ARCH(2)

# %%
model_arch_2 = arch_model(df['returns'], mean="Constant", vol='ARCH', p=2, q=0)
model_arch_2_fit = model_arch_2.fit()
print(model_arch_2_fit.summary())
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 34336.61062838968
# Iteration:      2,   Func. Count:     15,   Neg. LLF: 11809.810463437398
# Iteration:      3,   Func. Count:     24,   Neg. LLF: 7900.582867042022
# Iteration:      4,   Func. Count:     31,   Neg. LLF: 7647.101576187482
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 8810.02930517937
# Iteration:      6,   Func. Count:     44,   Neg. LLF: 7449.551200532487
# Iteration:      7,   Func. Count:     49,   Neg. LLF: 7449.545177539265
# Iteration:      8,   Func. Count:     54,   Neg. LLF: 7449.545164098316
# Iteration:      9,   Func. Count:     58,   Neg. LLF: 7449.545164098206
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7449.545164098316
#             Iterations: 9
#             Function evaluations: 58
#             Gradient evaluations: 9
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -7449.55
# Distribution:                  Normal   AIC:                           14907.1
# Method:            Maximum Likelihood   BIC:                           14933.2
#                                         No. Observations:                 5020
# Date:                Fri, Aug 08 2025   Df Residuals:                     5019
# Time:                        17:39:18   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0484  1.401e-02      3.455  5.495e-04 [2.095e-02,7.585e-02]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# omega          0.6978  3.564e-02     19.580  2.272e-85 [  0.628,  0.768]
# alpha[1]       0.2202  3.474e-02      6.339  2.311e-10 [  0.152,  0.288]
# alpha[2]       0.2783  3.645e-02      7.635  2.260e-14 [  0.207,  0.350]
# ========================================================================
#
# Covariance estimator: robust

# %%
model_arch_3 = arch_model(df['returns'], mean="Constant", vol='ARCH', p=3, q=0)
model_arch_3_fit = model_arch_3.fit()
print(model_arch_3_fit.summary())
# Out:
# Iteration:      1,   Func. Count:      7,   Neg. LLF: 39962.465851469606
# Iteration:      2,   Func. Count:     18,   Neg. LLF: 11954.630689597143
# Iteration:      3,   Func. Count:     27,   Neg. LLF: 8336.666751802351
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 7489.93945684613
# Iteration:      5,   Func. Count:     41,   Neg. LLF: 7496.4079308108885
# Iteration:      6,   Func. Count:     48,   Neg. LLF: 7393.754032519646
# Iteration:      7,   Func. Count:     56,   Neg. LLF: 7301.714171954324
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 7277.050581173273
# Iteration:      9,   Func. Count:     69,   Neg. LLF: 7277.050453151904
# Iteration:     10,   Func. Count:     75,   Neg. LLF: 7277.050452148393
# Iteration:     11,   Func. Count:     80,   Neg. LLF: 7277.0504521483745
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7277.050452148393
#             Iterations: 11
#             Function evaluations: 80
#             Gradient evaluations: 11
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -7277.05
# Distribution:                  Normal   AIC:                           14564.1
# Method:            Maximum Likelihood   BIC:                           14596.7
#                                         No. Observations:                 5020
# Date:                Fri, Aug 08 2025   Df Residuals:                     5019
# Time:                        17:39:18   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0529  1.316e-02      4.018  5.875e-05 [2.707e-02,7.865e-02]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# omega          0.5012  2.834e-02     17.685  5.505e-70 [  0.446,  0.557]
# alpha[1]       0.1570  2.649e-02      5.926  3.108e-09 [  0.105,  0.209]
# alpha[2]       0.2197  2.588e-02      8.489  2.077e-17 [  0.169,  0.270]
# alpha[3]       0.2804  3.354e-02      8.359  6.302e-17 [  0.215,  0.346]
# ========================================================================
#
# Covariance estimator: robust

# %% [markdown]
# # General Framework for ARCH and GARCH

# %%
from IPython.display import Image

Image('D:/D/UMD/Projects/Time series models/Vol_modelling_steps.png')

# %% [markdown]
# # ARCH Model

# %%
# plotting the returns
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['returns'], label='Returns', color='blue')
plt.title('Returns')
plt.legend()
plt.show()

# %% [markdown]
# ## 1. Descriptive statistics: ACF

# %%
# plotting the acf of returns
sgt.plot_acf(df.returns, lags=40, zero=False, alpha=0.05)
plt.ylim(-0.1, 0.1)  # Zoom y-axis
plt.title('ACF of Returns')
plt.show()

# %%
# plotting the acf of squared returns
sgt.plot_acf(df.sq_returns, lags=40, zero=False, alpha=0.05)
plt.ylim(-0.1, 0.3)  # Zoom y-axis
plt.title('ACF of Squared Returns')
plt.show()

# %% [markdown]
# ## 2. Estimate mean process: AR model

# %% [markdown]
# ### 2.1 order determination: PACF

# %%
# plot the pacf of returns
sgt.plot_pacf(df['returns'], lags=40, zero=False, alpha=0.05)
plt.ylim(-0.1, 0.1)  # Zoom y-axis
plt.title('PACF of Returns')
plt.show()

# %% [markdown]
# ### 2.2 order determination: AIC or BIC

# %%
# calculate AIC and BIC for AR models

BIC = np.zeros(11)
AIC = np.zeros(11)

for i in range(1, 11):
    model = ARIMA(df['returns'], order=(i, 0, 0))
    results = model.fit()
    BIC[i] = results.bic
    AIC[i] = results.aic

# %%
# plot the AIC and BIC
plt.figure(figsize=(12, 6))
plt.plot(range(1, 11), AIC[1:], label='AIC', marker='o')
plt.plot(range(1, 11), BIC[1:], label='BIC', marker='o')
plt.title('AIC and BIC for AR Models')
plt.xlabel('Order of AR Model')
plt.ylabel('Information Criterion')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# * From the above graph, we should choose AR model with 6 lags i.e **AR(6)**

# %% [markdown]
# ### 2.3 Estimate the parameters of the AR model

# %%
model_ar_6 = ARIMA(df['returns'], order=(6, 0, 0))
results_ar_6 = model_ar_6.fit()
print(results_ar_6.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                 ARIMA(6, 0, 0)   Log Likelihood               -7886.945
# Date:                Fri, 08 Aug 2025   AIC                          15789.890
# Time:                        17:39:30   BIC                          15842.059
# Sample:                    01-10-1994   HQIC                         15808.170
#                          - 04-05-2013
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0189      0.014      1.324      0.186      -0.009       0.047
# ar.L1         -0.0245      0.009     -2.640      0.008      -0.043      -0.006
# ar.L2         -0.0523      0.008     -6.505      0.000      -0.068      -0.037
# ar.L3         -0.0870      0.008    -10.853      0.000      -0.103      -0.071
# ar.L4          0.0424      0.008      5.133      0.000       0.026       0.059
# ar.L5         -0.0607      0.008     -7.568      0.000      -0.076      -0.045
# ar.L6         -0.0466      0.009     -5.216      0.000      -0.064      -0.029
# sigma2         1.3557      0.015     92.513      0.000       1.327       1.384
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              6487.37
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.00   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## 3. Volatility Modelling

# %% [markdown]
# ### 3.1. Test for ARCH effects

# %%
# plot the pacf of the squared returns
sgt.plot_pacf(df['sq_returns'], lags=40, zero=False, alpha=0.05)
plt.ylim(-0.1, 0.3)  # Zoom y-axis
plt.title('PACF of Squared Returns')
plt.show()

# %% [markdown]
# * Based on the PACF graph, volatility is serially correlated which could be noticed from the first few significant lags.

# %% [markdown]
# ### 3.2.  Testing for ARCH effects

# %%
# Engle test for ARCH effects which prints p value
from statsmodels.stats.diagnostic import het_arch
arch_test = het_arch(df['returns'])
print(f"Engle's ARCH test p-value: {arch_test[1]}")
# Out:
# Engle's ARCH test p-value: 5.907033417727355e-229

# %% [markdown]
# * This significant p value proves that we can reject the null hypothesis which says that there is no autocorrelation in volatility.

# %% [markdown]
# ### 3.3. Estimate ARCH model

# %% [markdown]
# ### Estimate ARCH(1) model

# %%
model_arch_1 = arch_model(df['returns'], mean="constant", vol='ARCH', p=1, q=0)
model_arch_1_fit = model_arch_1.fit(disp='off')
print(model_arch_1_fit.summary())
# Out:
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -7660.09
# Distribution:                  Normal   AIC:                           15326.2
# Method:            Maximum Likelihood   BIC:                           15345.7
#                                         No. Observations:                 5020
# Date:                Fri, Aug 08 2025   Df Residuals:                     5019
# Time:                        17:39:30   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0345  1.603e-02      2.151  3.147e-02 [3.063e-03,6.590e-02]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# omega          0.9206  4.309e-02     21.365 2.855e-101 [  0.836,  1.005]
# alpha[1]       0.3684  5.040e-02      7.310  2.673e-13 [  0.270,  0.467]
# ========================================================================
#
# Covariance estimator: robust

# %%
model_arch_1 = arch_model(df['returns'], mean="AR", lags=6, vol='ARCH', p=12, q=0)
model_arch_1_fit = model_arch_1.fit(disp='off')
print(model_arch_1_fit.summary())
# Out:
#                            AR - ARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.012
# Mean Model:                        AR   Adj. R-squared:                  0.011
# Vol Model:                       ARCH   Log-Likelihood:               -6966.95
# Distribution:                  Normal   AIC:                           13973.9
# Method:            Maximum Likelihood   BIC:                           14104.3
#                                         No. Observations:                 5014
# Date:                Fri, Aug 08 2025   Df Residuals:                     5007
# Time:                        17:39:30   Df Model:                            7
#                                    Mean Model
# ===============================================================================
#                   coef    std err          t      P>|t|        95.0% Conf. Int.
# -------------------------------------------------------------------------------
# Const           0.0588  1.260e-02      4.670  3.011e-06   [3.414e-02,8.351e-02]
# returns[1]     -0.0207  1.448e-02     -1.433      0.152  [-4.912e-02,7.632e-03]
# returns[2]     -0.0234  1.499e-02     -1.559      0.119  [-5.274e-02,6.010e-03]
# returns[3]     -0.0492  1.527e-02     -3.222  1.271e-03 [-7.913e-02,-1.928e-02]
# returns[4] -2.3285e-03  1.519e-02     -0.153      0.878  [-3.209e-02,2.744e-02]
# returns[5]     -0.0476  1.505e-02     -3.163  1.560e-03 [-7.712e-02,-1.811e-02]
# returns[6]     -0.0318  1.529e-02     -2.079  3.760e-02 [-6.177e-02,-1.824e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.1940  2.156e-02      9.000  2.260e-19     [  0.152,  0.236]
# alpha[1]       0.0573  1.727e-02      3.317  9.088e-04 [2.344e-02,9.114e-02]
# alpha[2]       0.1139  1.986e-02      5.733  9.880e-09   [7.494e-02,  0.153]
# alpha[3]       0.1288  2.531e-02      5.087  3.629e-07   [7.917e-02,  0.178]
# alpha[4]       0.0912  2.147e-02      4.248  2.155e-05   [4.913e-02,  0.133]
# alpha[5]       0.0730  1.747e-02      4.180  2.921e-05   [3.878e-02,  0.107]
# alpha[6]       0.0888  1.928e-02      4.607  4.080e-06   [5.104e-02,  0.127]
# alpha[7]       0.0460  1.785e-02      2.576  9.990e-03 [1.100e-02,8.095e-02]
# alpha[8]       0.0676  1.794e-02      3.765  1.666e-04   [3.239e-02,  0.103]
# alpha[9]       0.0366  1.630e-02      2.245  2.477e-02 [4.648e-03,6.856e-02]
# alpha[10]      0.0372  1.590e-02      2.339  1.933e-02 [6.028e-03,6.834e-02]
# alpha[11]      0.0796  1.731e-02      4.601  4.210e-06   [4.570e-02,  0.114]
# alpha[12]      0.0471  1.860e-02      2.534  1.127e-02 [1.068e-02,8.358e-02]
# ============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# ### 📌 Should We Use a Constant or AR Process for the Mean in ARCH Models?
#
# #### ✅ Does ARCH Assume a Time-Invariant Mean?
#
# Yes. The **basic ARCH model** assumes that the **mean of returns is constant** over time. The model is:
#
# $$
# r_t = \mu + \epsilon_t, \quad \epsilon_t \sim \mathcal{N}(0, \sigma_t^2)
# $$
#
# $$
# \sigma_t^2 = \omega + \alpha_1 \epsilon_{t-1}^2 + \alpha_2 \epsilon_{t-2}^2 + \cdots + \alpha_q \epsilon_{t-q}^2
# $$
#
# - \(\mu\) is **constant** — this is the **time-invariant mean assumption**.
# - The **volatility** \(\sigma_t^2\) is **time-varying** and driven by past squared shocks.
#
# ---
#
# #### 🤔 What Mean Models Can We Use in `arch_model()`?
#
# - `mean="Zero"` → assumes \(\mu = 0\)
# - `mean="Constant"` → assumes \(\mu\) is a fixed scalar
# - `mean="AR"` → allows time-varying \(\mu_t\) using autoregressive lags:
#   $$
#   \mu_t = \mu + \sum_{i=1}^{p} \phi_i r_{t-i}
#   $$
#
# ---
#
# #### 🧠 When Should You Use Each?
#
# | Situation                                      | Use Mean Model        |
# |-----------------------------------------------|------------------------|
# | No autocorrelation in returns                 | `mean="Constant"` or `"Zero"` |
# | Significant autocorrelation in returns        | `mean="AR"` with selected lags |
# | You only care about volatility modeling       | `mean="Constant"`     |
# | You're forecasting returns + volatility       | `mean="AR"`           |
# | You have external predictors (e.g. macro vars)| `mean="ARX"`          |
#
# ---
#
# #### ⚠️ Important:
#
# - If you **add AR terms**, you're **relaxing the ARCH assumption** of a fixed mean.
# - That's fine **if there's evidence** (via ACF, PACF, or model fit) that the mean is time-varying.
# - Otherwise, you're **overfitting** the mean while the real action is in the volatility.
#
# ---
#
# #### ✅ Summary:
#
# > The classic ARCH model assumes a **time-invariant mean**, so by default we should use `mean="Constant"` or `mean="Zero"` unless we have strong evidence to use an `AR` mean process.

# %% [markdown]
# ### ARCH(12) model with only selected lags

# %%
model_arch_12 = arch_model(df['returns'], mean="AR", lags=[3,5,6], vol='ARCH', p=12, q=0)
model_arch_12_fit = model_arch_12.fit(disp='off')
print(model_arch_12_fit.summary())
# Out:
#                            AR - ARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.009
# Mean Model:                        AR   Adj. R-squared:                  0.009
# Vol Model:                       ARCH   Log-Likelihood:               -6969.21
# Distribution:                  Normal   AIC:                           13972.4
# Method:            Maximum Likelihood   BIC:                           14083.3
#                                         No. Observations:                 5014
# Date:                Fri, Aug 08 2025   Df Residuals:                     5010
# Time:                        17:39:31   Df Model:                            4
#                                   Mean Model
# ==============================================================================
#                  coef    std err          t      P>|t|        95.0% Conf. Int.
# ------------------------------------------------------------------------------
# Const          0.0570  1.228e-02      4.639  3.499e-06   [3.289e-02,8.102e-02]
# returns[3]    -0.0485  1.528e-02     -3.171  1.518e-03 [-7.842e-02,-1.851e-02]
# returns[5]    -0.0461  1.505e-02     -3.064  2.186e-03 [-7.561e-02,-1.661e-02]
# returns[6]    -0.0306  1.526e-02     -2.002  4.524e-02 [-6.047e-02,-6.474e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.1939  2.156e-02      8.993  2.409e-19     [  0.152,  0.236]
# alpha[1]       0.0577  1.735e-02      3.324  8.880e-04 [2.367e-02,9.170e-02]
# alpha[2]       0.1128  1.980e-02      5.698  1.214e-08   [7.401e-02,  0.152]
# alpha[3]       0.1291  2.547e-02      5.068  4.029e-07   [7.916e-02,  0.179]
# alpha[4]       0.0920  2.144e-02      4.291  1.781e-05   [4.998e-02,  0.134]
# alpha[5]       0.0743  1.740e-02      4.272  1.938e-05   [4.022e-02,  0.108]
# alpha[6]       0.0879  1.920e-02      4.581  4.631e-06   [5.031e-02,  0.126]
# alpha[7]       0.0459  1.787e-02      2.570  1.016e-02 [1.091e-02,8.097e-02]
# alpha[8]       0.0685  1.802e-02      3.803  1.429e-04   [3.321e-02,  0.104]
# alpha[9]       0.0360  1.627e-02      2.215  2.675e-02 [4.152e-03,6.792e-02]
# alpha[10]      0.0371  1.586e-02      2.341  1.924e-02 [6.042e-03,6.822e-02]
# alpha[11]      0.0787  1.720e-02      4.572  4.824e-06   [4.494e-02,  0.112]
# alpha[12]      0.0473  1.884e-02      2.510  1.207e-02 [1.037e-02,8.422e-02]
# ============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# ### Simple GARCH Model

# %%
model_garch_1_1 = arch_model(df['returns'], mean="Constant", vol='GARCH', p=1, q=1)
model_garch_1_1_fit = model_garch_1_1.fit(disp='off')
print(model_garch_1_1_fit.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -6970.06
# Distribution:                  Normal   AIC:                           13948.1
# Method:            Maximum Likelihood   BIC:                           13974.2
#                                         No. Observations:                 5020
# Date:                Fri, Aug 08 2025   Df Residuals:                     5019
# Time:                        17:39:31   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0466  1.183e-02      3.939  8.187e-05 [2.342e-02,6.981e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0109  3.004e-03      3.640  2.724e-04 [5.048e-03,1.682e-02]
# alpha[1]       0.0835  1.071e-02      7.794  6.476e-15   [6.249e-02,  0.104]
# beta[1]        0.9089  1.148e-02     79.168      0.000     [  0.886,  0.931]
# ============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# ### Higher lag GARCH Models

# %%
model_garch_1_2 = arch_model(df['returns'], mean="Constant", vol='GARCH', p=1, q=1)
model_garch_1_2_fit = model_garch_1_2.fit(disp='off')
print(model_garch_1_2_fit.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -6970.06
# Distribution:                  Normal   AIC:                           13948.1
# Method:            Maximum Likelihood   BIC:                           13974.2
#                                         No. Observations:                 5020
# Date:                Fri, Aug 08 2025   Df Residuals:                     5019
# Time:                        17:39:31   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0466  1.183e-02      3.939  8.187e-05 [2.342e-02,6.981e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0109  3.004e-03      3.640  2.724e-04 [5.048e-03,1.682e-02]
# alpha[1]       0.0835  1.071e-02      7.794  6.476e-15   [6.249e-02,  0.104]
# beta[1]        0.9089  1.148e-02     79.168      0.000     [  0.886,  0.931]
# ============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# * GARCH(1,1) is the most optimal model which is proven mathematically.

# %% [markdown]
# ### Find a good garch model

# %%
df
# Out:
#             market_value   returns  sq_returns
# date
# 1994-01-10       3440.58 -0.156704    0.024556
# 1994-01-11       3413.77 -0.779229    0.607198
# 1994-01-12       3372.02 -1.222988    1.495700
# 1994-01-13       3360.01 -0.356166    0.126854
# 1994-01-14       3400.56  1.206842    1.456467
# ...                  ...       ...         ...
# 2013-04-01       6411.74  0.000000    0.000000
# 2013-04-02       6490.66  1.230867    1.515034
# 2013-04-03       6420.28 -1.084327    1.175766
# 2013-04-04       6344.11 -1.186397    1.407537
# 2013-04-05       6249.77 -1.487049    2.211314
#
# [5020 rows x 3 columns]

# %%
# Get the last date from df as start_date
start_date = df.index[-200]   

# Set end_date as "2014-01-01"
end_date = pd.to_datetime("2014-01-01")

# %%
# remove nan from df_comp
df_comp.dropna(inplace=True)

# %%
df_comp
# Out:
#             market_value   returns
# date
# 1994-01-10   3440.580000 -0.156704
# 1994-01-11   3413.770000 -0.779229
# 1994-01-12   3372.020000 -1.222988
# 1994-01-13   3360.010000 -0.356166
# 1994-01-14   3400.560000  1.206842
# ...                  ...       ...
# 2018-01-23   7731.827774  0.212382
# 2018-01-24   7643.428966 -1.143311
# 2018-01-25   7615.839954 -0.360951
# 2018-01-26   7665.541292  0.652605
# 2018-01-29   7671.533300  0.078168
#
# [6276 rows x 2 columns]

# %%
model_garch_1_1 = arch_model(df_comp['returns'], mean="AR", lags= [3,5,6], vol='GARCH', p=1, q=1)
model_garch_1_1_fit = model_garch_1_1.fit(last_obs= start_date , disp='off')
print(model_garch_1_1_fit.summary())
# Out:
#                            AR - GARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.009
# Mean Model:                        AR   Adj. R-squared:                  0.009
# Vol Model:                      GARCH   Log-Likelihood:               -6726.18
# Distribution:                  Normal   AIC:                           13466.4
# Method:            Maximum Likelihood   BIC:                           13511.7
#                                         No. Observations:                 4814
# Date:                Fri, Aug 08 2025   Df Residuals:                     4810
# Time:                        17:39:31   Df Model:                            4
#                                   Mean Model
# ==============================================================================
#                  coef    std err          t      P>|t|        95.0% Conf. Int.
# ------------------------------------------------------------------------------
# Const          0.0510  1.227e-02      4.160  3.183e-05   [2.700e-02,7.510e-02]
# returns[3]    -0.0434  1.525e-02     -2.846  4.423e-03 [-7.330e-02,-1.352e-02]
# returns[5]    -0.0416  1.515e-02     -2.747  6.005e-03 [-7.134e-02,-1.193e-02]
# returns[6]    -0.0343  1.502e-02     -2.283  2.246e-02 [-6.373e-02,-4.846e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0103  2.845e-03      3.612  3.035e-04 [4.701e-03,1.585e-02]
# alpha[1]       0.0850  1.034e-02      8.218  2.076e-16   [6.473e-02,  0.105]
# beta[1]        0.9086  1.088e-02     83.544      0.000     [  0.887,  0.930]
# ============================================================================
#
# Covariance estimator: robust

# %%
pred_garch = model_garch_1_1_fit.forecast(
    horizon=5,
    start = start_date,  # start forecasting from the last date in df
    align='target',        # put the forecast on the date it forecasts for
)

# %%
print(pred_garch.variance.iloc[-3:])
# Out:
#                  h.1       h.2       h.3       h.4       h.5
# date
# 2018-01-25  0.335403  0.232016  0.250089  0.264635  0.274792
# 2018-01-26  0.332031  0.343535  0.240810  0.259205  0.273239
# 2018-01-29  0.344220  0.340185  0.351615  0.249968  0.267845

# %%
pred_garch.residual_variance[start_date:].plot(figsize=(12, 6), title='GARCH(1,1) Forecasted Variance')
plt.xlabel('Date')
plt.ylabel('Forecasted Variance')

plt.show()

# %%
pred_garch = model_garch_1_1_fit.forecast(
    horizon=100,
    start = start_date,  # start forecasting from the last date in df
    align='target',        # put the forecast on the date it forecasts for
)

# %%
# i want to plot pred_garch.variance.iloc[-1:] for the next 100 days with h1, h2, h3,... on the x axis
pred_garch.variance.iloc[-1:]
# Out:
#               h.001     h.002     h.003     h.004     h.005     h.006  \
# date
# 2018-01-29  0.34422  0.340185  0.351615  0.249968  0.267845  0.282201
#
#                h.007     h.008    h.009     h.010  ...     h.091     h.092  \
# date                                               ...
# 2018-01-29  0.292499  0.301758  0.30739  0.323907  ...  0.937779  0.944511
#
#                h.093    h.094     h.095     h.096     h.097     h.098  \
# date
# 2018-01-29  0.963541  0.98447  1.005873  1.019673  0.979067  0.933193
#
#                h.099     h.100
# date
# 2018-01-29  0.942979  0.957474
#
# [1 rows x 100 columns]

# %%
# Extract the last row (forecast values)
forecast_values = pred_garch.variance.iloc[-1].values

# Extract column names as x-axis labels
x_labels = pred_garch.variance.columns

# Plot
plt.figure(figsize=(12, 6))
plt.plot(x_labels, forecast_values, marker='o')
plt.xticks(rotation=90)  # Rotate labels for readability
# x axis labels are conjested so display them in frequency
plt.xticks(np.arange(0, len(x_labels), 10), rotation=90)  # Show every 10th label
plt.xlabel('Forecast Horizon')
plt.ylabel('Variance')
plt.title('GARCH Forecast Variance for Next 100 Days')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Multivariate Regression

# %%
# calculate returns

df_ret['ret_spx']  = df_ret['spx'].pct_change(1) * 100
df_ret['ret_dax']  = df_ret['dax'].pct_change(1) * 100
df_ret['ret_ftse'] = df_ret['ftse'].pct_change(1) * 100
df_ret['ret_nikkei'] = df_ret['nikkei'].pct_change(1) * 100

# %%
df_ret = df_ret[['ret_spx', 'ret_dax', 'ret_ftse', 'ret_nikkei']][1:]

# %%
df_ret, df_ret_test = df_ret[:size], df_ret[size:]

# %%
from statsmodels.tsa.api import VAR

# %%
model_var_ret = VAR(df_ret)
model_var_ret.select_order(20)
results_var_ret = model_var_ret.fit( ic='aic')

# %%
results_var_ret.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 08, Aug, 2025
# Time:                     17:39:34
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   0.476610
# Nobs:                     5016.00    HQIC:                  0.405681
# Log likelihood:          -29307.1    FPE:                    1.44400
# AIC:                     0.367417    Det(Omega_mle):         1.42007
# --------------------------------------------------------------------
# Results for equation ret_spx
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.035953         0.017032            2.111           0.035
# L1.ret_spx           -0.112527         0.018128           -6.207           0.000
# L1.ret_dax            0.065501         0.019488            3.361           0.001
# L1.ret_ftse          -0.011822         0.025114           -0.471           0.638
# L1.ret_nikkei        -0.016628         0.013410           -1.240           0.215
# L2.ret_spx           -0.041302         0.020905           -1.976           0.048
# L2.ret_dax            0.020869         0.019705            1.059           0.290
# L2.ret_ftse          -0.037316         0.025553           -1.460           0.144
# L2.ret_nikkei        -0.015667         0.013573           -1.154           0.248
# L3.ret_spx           -0.002215         0.021186           -0.105           0.917
# L3.ret_dax           -0.009658         0.019722           -0.490           0.624
# L3.ret_ftse           0.009711         0.025451            0.382           0.703
# L3.ret_nikkei         0.014505         0.013590            1.067           0.286
# L4.ret_spx           -0.046827         0.021069           -2.223           0.026
# L4.ret_dax           -0.004971         0.019705           -0.252           0.801
# L4.ret_ftse           0.059357         0.025406            2.336           0.019
# L4.ret_nikkei        -0.011435         0.013574           -0.842           0.400
# L5.ret_spx           -0.033300         0.019822           -1.680           0.093
# L5.ret_dax            0.013890         0.019571            0.710           0.478
# L5.ret_ftse          -0.050124         0.024394           -2.055           0.040
# L5.ret_nikkei         0.000695         0.012147            0.057           0.954
# ================================================================================
#
# Results for equation ret_dax
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.029704         0.020507            1.448           0.147
# L1.ret_spx            0.410950         0.021827           18.828           0.000
# L1.ret_dax           -0.120086         0.023465           -5.118           0.000
# L1.ret_ftse          -0.152882         0.030238           -5.056           0.000
# L1.ret_nikkei        -0.043694         0.016147           -2.706           0.007
# L2.ret_spx            0.175246         0.025171            6.962           0.000
# L2.ret_dax           -0.057908         0.023726           -2.441           0.015
# L2.ret_ftse          -0.062021         0.030767           -2.016           0.044
# L2.ret_nikkei        -0.033179         0.016342           -2.030           0.042
# L3.ret_spx            0.104715         0.025508            4.105           0.000
# L3.ret_dax           -0.057714         0.023746           -2.430           0.015
# L3.ret_ftse          -0.022665         0.030644           -0.740           0.460
# L3.ret_nikkei         0.020535         0.016362            1.255           0.209
# L4.ret_spx           -0.000584         0.025368           -0.023           0.982
# L4.ret_dax           -0.020579         0.023725           -0.867           0.386
# L4.ret_ftse           0.062080         0.030590            2.029           0.042
# L4.ret_nikkei         0.008010         0.016343            0.490           0.624
# L5.ret_spx           -0.017774         0.023866           -0.745           0.456
# L5.ret_dax            0.031555         0.023565            1.339           0.181
# L5.ret_ftse          -0.111809         0.029372           -3.807           0.000
# L5.ret_nikkei         0.011061         0.014625            0.756           0.449
# ================================================================================
#
# Results for equation ret_ftse
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.009769         0.015423            0.633           0.526
# L1.ret_spx            0.428402         0.016416           26.097           0.000
# L1.ret_dax           -0.053208         0.017648           -3.015           0.003
# L1.ret_ftse          -0.218441         0.022742           -9.605           0.000
# L1.ret_nikkei        -0.048748         0.012144           -4.014           0.000
# L2.ret_spx            0.160752         0.018931            8.492           0.000
# L2.ret_dax           -0.048374         0.017844           -2.711           0.007
# L2.ret_ftse          -0.083809         0.023140           -3.622           0.000
# L2.ret_nikkei        -0.026647         0.012291           -2.168           0.030
# L3.ret_spx            0.107527         0.019185            5.605           0.000
# L3.ret_dax           -0.035682         0.017860           -1.998           0.046
# L3.ret_ftse          -0.091684         0.023047           -3.978           0.000
# L3.ret_nikkei         0.009044         0.012306            0.735           0.462
# L4.ret_spx            0.018720         0.019079            0.981           0.326
# L4.ret_dax           -0.005722         0.017843           -0.321           0.748
# L4.ret_ftse           0.013938         0.023007            0.606           0.545
# L4.ret_nikkei         0.010471         0.012292            0.852           0.394
# L5.ret_spx            0.013377         0.017950            0.745           0.456
# L5.ret_dax            0.047181         0.017723            2.662           0.008
# L5.ret_ftse          -0.110749         0.022090           -5.013           0.000
# L5.ret_nikkei        -0.017789         0.011000           -1.617           0.106
# ================================================================================
#
# Results for equation ret_nikkei
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.021190         0.018403           -1.151           0.250
# L1.ret_spx            0.423135         0.019587           21.603           0.000
# L1.ret_dax            0.085718         0.021056            4.071           0.000
# L1.ret_ftse           0.142678         0.027135            5.258           0.000
# L1.ret_nikkei        -0.153549         0.014490          -10.597           0.000
# L2.ret_spx            0.079764         0.022587            3.531           0.000
# L2.ret_dax            0.033242         0.021291            1.561           0.118
# L2.ret_ftse          -0.042349         0.027609           -1.534           0.125
# L2.ret_nikkei        -0.046959         0.014665           -3.202           0.001
# L3.ret_spx            0.056448         0.022891            2.466           0.014
# L3.ret_dax            0.005062         0.021309            0.238           0.812
# L3.ret_ftse          -0.023685         0.027499           -0.861           0.389
# L3.ret_nikkei        -0.015702         0.014683           -1.069           0.285
# L4.ret_spx            0.016219         0.022764            0.712           0.476
# L4.ret_dax           -0.019673         0.021290           -0.924           0.355
# L4.ret_ftse           0.046152         0.027451            1.681           0.093
# L4.ret_nikkei        -0.023470         0.014666           -1.600           0.110
# L5.ret_spx           -0.000058         0.021417           -0.003           0.998
# L5.ret_dax            0.041029         0.021146            1.940           0.052
# L5.ret_ftse           0.008054         0.026357            0.306           0.760
# L5.ret_nikkei        -0.013178         0.013124           -1.004           0.315
# ================================================================================
#
# Correlation matrix of residuals
#                ret_spx   ret_dax  ret_ftse  ret_nikkei
# ret_spx       1.000000  0.604314  0.569177    0.151045
# ret_dax       0.604314  1.000000  0.772162    0.201677
# ret_ftse      0.569177  0.772162  1.000000    0.210779
# ret_nikkei    0.151045  0.201677  0.210779    1.000000

# %%
lag_order_ret = results_var_ret.k_ar
var_pred_ret = results_var_ret.forecast(df_ret.values[-lag_order_ret:], len(df_ret_test[start_date:end_date]))

df_pred_ret = pd.DataFrame(
    var_pred_ret,
    index=df_ret_test.loc[start_date:end_date].index,
    columns=df_ret_test.loc[start_date:end_date].columns[0:4]
)

df_pred_ret.ret_nikkei.loc[start_date:end_date].plot(figsize=(12, 6))
# plotting the predicted returns
df_ret_test.ret_nikkei.loc[start_date:end_date].plot(figsize=(12, 6))
plt.legend( ['Actual Returns', 'Predicted Returns'])
plt.title('Comparison of Predicted and Actual Returns for Nikkei')
plt.grid()
plt.xlabel('Date')
plt.ylabel('Returns')
plt.show()

# %%
results_var_ret.plot_forecast(1000)
